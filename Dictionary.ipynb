# %%
info = {
    "name": "Archish Chandra",
    "age": 20,
    "gender": "Male",
}
print(info)

print("name:",info["name"])
# Out:
# {'name': 'Archish Chandra', 'age': 20, 'gender': 'Male'}
# name: Archish Chandra

# %%
info = {
    "name": "Archish Chandra",
    "age": 20,
    "gender": "Male",
}

values_list = list(info.values())

print("List of values:", values_list)
# Out:
# List of values: ['Archish Chandra', 20, 'Male']

# %%
info = {
    "name": "Archish Chandra",
    "age": 20,
    "gender": "Male",
}

info["age"] = 22

print(info)
print(info["age"])
# Out:
# {'name': 'Archish Chandra', 'age': 22, 'gender': 'Male'}
# 22

# %%
info = {
    "name": "Archish Chandra",
    "age": 20,
    "gender": "Male",
}

for key in info:
    print(key)
# Out:
# name
# age
# gender

# %%
info = {
    "student1": {"name": "Archish", "age": 20},
    "student2": {"name": "Rahul", "age": 21},
    "student3": {"name": "Aman", "age": 22}
}

print(info)
# Out:
# {'student1': {'name': 'Archish', 'age': 20}, 'student2': {'name': 'Rahul', 'age': 21}, 'student3': {'name': 'Aman', 'age': 22}}

# %%
d1 = {"name": "Archish"}
d2 = {"age": 20}
d3 = {"course": "B.Tech"}

info = {
    "info1": d1,
    "info2": d2,
    "info3": d3
}

print(info)
# Out:
# {'info1': {'name': 'Archish'}, 'info2': {'age': 20}, 'info3': {'course': 'B.Tech'}}

# %%
list1 = ["name", "age", "course"]
list2 = ["Archish", 20, "B.Tech"]

result = dict(zip(list1, list2))
print(result)
# Out:
# {'name': 'Archish', 'age': 20, 'course': 'B.Tech'}

# %%
d1 = {"a": 1, "b": 5}
d2 = {"c": 3, "d": 4}

merged = d1 | d2
print(merged)
# Out:
# {'a': 1, 'b': 5, 'c': 3, 'd': 4}
